# %% [markdown]
# <a href="https://colab.research.google.com/github/olabe3/NeuralNetworks/blob/master/zhgyak2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread('1.jpg')
img2 = cv2.imread('2.jpg')
img3 = cv2.imread('3.jpg')

img1 = cv2.cvtColor(img1,cv2.COLOR_RGB2BGR)
img2 = cv2.cvtColor(img2,cv2.COLOR_RGB2BGR)
img3 = cv2.cvtColor(img3,cv2.COLOR_RGB2BGR)
plt.imshow(img3)

# %%
height = img3.shape[0]
width = img3.shape[1]

height = int(height / 2)
width = int(width / 2)

img = cv2.resize(img3, (width, height), interpolation=cv2.INTER_CUBIC)

plt.title("Resized image")
plt.imshow(img3)
plt.show()

# %%
plt.subplot(3, 1, 1)
plt.title("Different color channels")
plt.imshow(img1[:, :, 0])
plt.subplot(3, 1, 2)
plt.imshow(img2[:, :, 1])
plt.subplot(3, 1, 3)
plt.imshow(img3[:, :, 2])
plt.show()
